# %%
import requests
from time import sleep
from bs4 import BeautifulSoup

# %%
# Initialize a counter for the page number
page_number = 1

# Initialize an empty list to store the clinic listings
clinic_listings = []
clinic_addresses = []
clinic_type = []
clinic_reviews = []
clinic_count_reviews = []
links = []

# Loop until there are no more pages
while True:
    # Construct the URL with the current page number
    url = f"https://www.local.ch/en/q/Switzerland/clinique?page={page_number}&rid=j6VE&slot=tel"

    # Send a request to the URL and get the response
    response = requests.get(url, timeout = 20)

    # Check if the response was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Find all div elements with class "lui-card"
        listings = soup.find_all("div", class_="card-info-element")
        
        addresses = soup.find_all('div', class_ = "card-info-address")
        
        cl_type = soup.find_all('div', class_ = "card-info-category")
        
        link = soup.find_all('div', "entry-card-info-element entry-card-info-element-first")

        # Check if any listings were found
        if listings:
            # Add the listings to the list of clinic listings
            clinic_listings.extend(listings)
            clinic_addresses.extend(addresses)
            links.extend(link)
            clinic_type.extend(cl_type)
            for i in links:
                url2 = i.find('a')['href']
                r = requests.get(url2, timeout = 20)
                if r.status_code == 200:
                    soup2 = BeautifulSoup(r.content, "html.parser")
                    rev = soup2.find_all('div', "feedback-summary-ratings-value lui-margin-bottom-xxs")
                    clinic_reviews.extend(rev)
                    no_review = soup2.find_all('div', "text-muted text-nowrap lui-margin-top-xs")
                    clinic_count_reviews.extend(no_review)
            # Increment the page number
            print(f'Page {page_number} completed')
            page_number += 1
            sleep(2)
        else:
            # If no listings were found, break the loop
            break
    else:
        # If the response was not successful, break the loop
        break

# Print the number of clinic listings found
print(f"Number of clinic listings: {len(clinic_listings)}")
# Out:
# Page 1 completed
# Page 2 completed
# Page 3 completed
# Page 4 completed
# Page 5 completed
# Page 6 completed
# Page 7 completed
# Page 8 completed
# Page 9 completed
# Page 10 completed
# Page 11 completed
# Page 12 completed
# Page 13 completed
# Page 14 completed
# Page 15 completed
# Page 16 completed
# Page 17 completed
# Page 18 completed
# Page 19 completed
# Page 20 completed
# Page 21 completed
# Page 22 completed
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     442             try:
# --> 443                 yield
#     444
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     814             while True:
# --> 815                 self._update_chunk_length()
#     816                 if self.chunk_left == 0:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     744             return
# --> 745         line = self._fp.fp.readline()
#     746         line = line.split(b";", 1)[0]
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     843             if self._original_response:
# --> 844                 self._original_response.close()
#     845
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     459                 # This includes IncompleteRead.
# --> 460                 raise ProtocolError("Connection broken: %r" % e, e)
#     461
#
# ProtocolError: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14496\3538918246.py in <module>
#      41             for i in links:
#      42                 url2 = i.find('a')['href']
# ---> 43                 r = requests.get(url2, timeout = 20)
#      44                 if r.status_code == 200:
#      45                     soup2 = BeautifulSoup(r.content, "html.parser")
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
# --> 818                     raise ChunkedEncodingError(e)
#     819                 except DecodeError as e:
#     820                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
# Initialize an empty list to store the clinic listings
print(len(clinic_listings))
print(len(clinic_addresses))
print(len(clinic_type))
print(len(clinic_reviews))
print(len(clinic_count_reviews))
print(len(links))
# Out:
# 460
# 230
# 230
# 1933
# 1933
# 226

# %%
s = soup.find_all('div', "entry-card-info-element entry-card-info-element-first")

# %%
s[1].find('a')['href']
# Out:
# 'https://www.local.ch/en/d/zuerich/8032/plastic-reconstructive-and-aesthetic-surgery/klinik-professor-sailer-awE97k2lERPomYfllk1LNA'

# %%
clinic_names = []
for names in clinic_listings:
    try:
        name_element = names.find("h2", class_="lui-margin-vertical-zero card-info-title")
        name = name_element.text.strip()
        clinic_names.append(name)
    except AttributeError:
        continue

# %%
clinic_address = []
for address in clinic_listings:
    try:
        add_element = address.find('div', "card-info-address")
        name = name_element.text.strip()
        clinic_address.append(name)
    except AttributeError:
        continue

# %%
len(clinic_listings)
# Out:
# 2000

# %%
cd = list()
for i in clinic_listings:
    a = i.find('div', "card-info-address")
    if a:
        cd.append(a.text.strip())

# %%
len(cd)
# Out:
# 1000

# %%
aa = soup.find('div', "entry-card-info-element entry-card-info-element-first").find('a')['href']
aa
# Out:
# 'https://www.local.ch/en/d/yverdon-les-bains/1400/psychology/blanchard-sabine-CdDVQQYzClBl2kQQBbtbPw'

# %%
soup.find('div', class_ = "card-info-category").find('span').text
# Out:
# 'Psychology • Medical massage'

# %%
ax = "https://www.local.ch/en/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg"

# %%
r = requests.get(ax)

# %%
sp = BeautifulSoup(r.content, "html.parser")

# %%
sp
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://www.googletagmanager.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://cdn.cookielaw.org" rel="preconnect"/>
# <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload"/>
# <!-- Google Tag Manager -->
# <script>window.dataLayer = window.dataLayer || []; window.dataLayer.push.apply(window.dataLayer, [{"A/B/n Test":"Version B \"New DE\""},{"AverageRating":3.6},{"DetailEntryCity":"Liestal"},{"DetailEntryName":"Kantonsspital Baselland Liestal"},{"EntryType":"Professional"},{"Feedbacks":true},{"Language":"en"},{"PageType":"DetailEntry"},{"Link":true},{"LinkReservation":false},{"LocalCategory":"Hospital"},{"LoginType":"Visitor"},{"OnlineEntryID":"lAGqVlMCSeL7uV0QLTUWhg"},{"RestoBooking":false},{"Slot":"details"},{"CTAPlacement":"DetailEntry"},{"user_status":"visitor"},{"page_language":"en"}]); window.dataLayerDefaults = {"A/B/n Test":"Version B \"New DE\"","AverageRating":3.6,"DetailEntryCity":"Liestal","DetailEntryName":"Kantonsspital Baselland Liestal","EntryType":"Professional","Feedbacks":true,"Language":"en","PageType":"DetailEntry","Link":true,"LinkReservation":false,"LocalCategory":"Hospital","LoginType":"Visitor","OnlineEntryID":"lAGqVlMCSeL7uV0QLTUWhg","RestoBooking":false,"Slot":"details","CTAPlacement":"DetailEntry","user_status":"visitor","page_language":"en"}</script>
# <!-- End Google Tag Manager -->
# <!-- Google Optimize -->
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-M62PK9K"></script>
# <!-- End Google Optimize -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NT77MB');</script>
# <!-- End Google Tag Manager -->
# <script async="" charset="UTF-8" data-document-language="true" data-domain-script="3c5ea0bc-e4af-4c40-b35b-132e2bba9d4c" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script>
#   function OptanonWrapper() { }
# </script>
# <title>Kantonsspital Baselland Liestal Hospital in Liestal - Opening hours | Address | Phone
# </title>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="/re6hm0K8GH2W0xavMl1DyxKsyeAtDK4USq1iyyZRcwSESOaRGensd2hT9jYeFckohlB1UJrxif1NC+oGEqwQg==" name="csrf-token">
# <link href="/details/assets/local_favicon/local_favicon-29494f44ac3bfd600e3516715eb833612a24e472a16a3bceda7a7bf737b23d33.ico" rel="icon" type="image/x-icon">
# <link href="/details/assets/local_favicon/local_icon_128-b31be62573dfb2bb118fa2a9067e2a7b5f95027417b2c066ced0214a4786dbd6.png" rel="icon" sizes="128x128" type="image/png">
# <link href="/details/assets/local_favicon/local_icon_192-eb4c9f2cc9ef80fb69621dd20c28a187a2d5dced852c00f208fd0ba28a0084f9.png" rel="icon" sizes="192x192" type="image/png">
# <link href="/details/assets/local_favicon/local_icon_180-fd4da6dc8e989959cd4c84fcfb4b59bf4c5d8aed6e441af96d7643d221fd56cf.png" rel="apple-touch-icon" type="image/png">
# <link href="/details/assets/local_favicon/local_icon_76-a5b7ce0fd870ff36cbc953f26a79e27cea9dd72cbd38eb643b0847cfdd440005.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="/details/assets/local_favicon/local_icon_120-f7bfcacdba1b1daab23d3b95dd70824629e9346fa89cf73397104451480f6893.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="/details/assets/local_favicon/local_icon_152-a0ee035152f382e725ed43f7cccbb6ae040fadda6fbc9eb6ff395fb1135207b3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="/details/assets/local_favicon/local_icon_167-e8012d4fa72a21479ab1137aab00a02a7ffc6ae5c30a0ba37be85052a6f762eb.png" rel="apple-touch-icon" sizes="167x167" type="image/png"/>
# <link href="/details/assets/local_favicon/local_icon_180-fd4da6dc8e989959cd4c84fcfb4b59bf4c5d8aed6e441af96d7643d221fd56cf.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <meta content="#009ee3" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="#009ee3" name="theme-color"/>
# <meta content="#009ee3" name="msapplication-TileColor"/>
# <meta content="https://www.local.ch/details/assets/local_favicon/local_icon_192-eb4c9f2cc9ef80fb69621dd20c28a187a2d5dced852c00f208fd0ba28a0084f9.png" name="msapplication-TileImage"/>
# <meta content="Kantonsspital Baselland Liestal Hospital 🏥 in Liestal ⌚ Opening hours ✉ Address ☎ Phone ★ 8 ratings ✅ on local.ch" name="description" property=""/>
# <meta content="website" name="" property="og:type"/>
# <meta content="Kantonsspital Baselland Liestal" name="" property="og:title"/>
# <meta content="https://www.local.ch/en/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" name="" property="og:url"/>
# <meta content="en" name="" property="og:locale"/>
# <meta content="https://bin.staticlocal.ch/logo-ad/fd/fd8c2874683482038a2edaa4c4ee4a3ae73e4e9a/upload1.jpg" name="" property="og:image"/>
# <meta content="de" name="" property="og:locale:alternate"/>
# <meta content="it" name="" property="og:locale:alternate"/>
# <meta content="fr" name="" property="og:locale:alternate"/>
# <link href="android-app://ch.local.android/localch/tel/entry/lAGqVlMCSeL7uV0QLTUWhg" rel="alternate"/>
# <meta href="localch://tel/search?phonebook_id=lAGqVlMCSeL7uV0QLTUWhg" property="al:ios:url"/>
# <link href="https://www.local.ch/en/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" rel="canonical"/>
# <link href="https://www.local.ch/de/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" hreflang="x-default" rel="alternate"/>
# <link href="https://www.local.ch/de/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" hreflang="de-ch" rel="alternate"/>
# <link href="https://www.local.ch/en/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" hreflang="en-ch" rel="alternate"/>
# <link href="https://www.local.ch/it/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" hreflang="it-ch" rel="alternate"/>
# <link href="https://www.local.ch/fr/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" hreflang="fr-ch" rel="alternate"/>
# <link href="https://bin.staticlocal.ch/local-ui/29.3.0/stylesheets/local-ui.min.css" media="all" rel="stylesheet">
# <link href="/details/assets/application-697183644f1ee3e81a8cb4b63ea302f2e9855ae2573d635bcecb3e419469c752.css" media="all" rel="stylesheet">
# </link></link></link></link></link></link></meta></meta></head>
# <body class="background-gray-lucid">
# <script>
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NT77MB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager -->
# <div class="hidden-print">
# <nav class="navbar navbar-default navbar-static-top" id="site-navigation">
# <div class="container-semi-fluid">
# <div aria-expanded="false" class="pull-left navbar-toggle collapsed" data-target="#slot-navigation-selector" data-toggle="collapse">
# <i class="icon-hamburger"></i>
# </div>
# <!-- / Languange Picker -->
# <ul class="nav pull-right" id="language-selector">
# <li class="dropdown dropdown-nav text-uppercase">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle navbar-link navbar-link-vertical-centered js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="dropdown-toggle" data-toggle="dropdown" href="#site-navigation-locale-dropdown">
# <span>
# en
# </span>
# <span class="caret caret-navbar"></span>
# </a>
# <ul class="dropdown-menu dropdown-menu-nav">
# <li>
# <a class="de js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="de" href="/de/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg">de</a>
# </li>
# <li>
# <a class="fr js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="fr" href="/fr/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg">fr</a>
# </li>
# <li>
# <a class="it js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="it" href="/it/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg">it</a>
# </li>
# </ul>
# </li>
# </ul>
# <!-- / User Navigation -->
# <ul class="nav pull-right nav-username">
# <li>
# <a class="cc-login js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Customer Center" href="/details/auth/localch?locale=en&amp;origin=https%3A%2F%2Fwww.local.ch%2Fen%2Fd%2Fliestal%2F4410%2Fhospital%2Fkantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg">Log in</a>
# </li>
# </ul>
# <div class="collapse navbar-collapse" id="slot-navigation-selector">
# <ul class="nav navbar-nav">
# <li class="menu-item">
# <a class="js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Www" href="https://www.local.ch/en" target="_top" title="local.ch - the official phonebook and yellow pages of Switzerland">Home</a>
# </li>
# <li class="menu-item">
# <a class="js-gtm-event" data-add-search-params="" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Tel" href="https://www.local.ch/en/tel" target="_top" title="Official phonebook of Switzerland – local.ch">Phone Book</a>
# </li>
# <li class="menu-item">
# <a class="js-gtm-event" data-add-search-params="" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Yellow" href="https://www.local.ch/en/yellow" target="_top" title="Switzerland's Yellow Pages at local.ch - Find a company quickly">The Yellow Pages</a>
# </li>
# <li class="menu-item">
# <a class="js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Free-table-search" href="https://www.local.ch/en/restaurants" target="_top" title="Find and book a free table in a restaurant">Book a table</a>
# </li>
# <li class="menu-item">
# <a class="js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Weather" href="https://www.local.ch/en/weather" target="_top" title="Weather">Weather</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="searchbar">
# <div class="container">
# <div class="row">
# <div class="col-xs-12">
# <div class="clearfix">
# <div class="searchbar-left">
# <a class="lui-logo js-gtm-event" data-gtm-action="click" data-gtm-category="Header" data-gtm-label="Logo" href="https://www.local.ch/en" title="Switzerland's official Phone Book by local.ch"><img alt="Logo local.ch" class="lui-logo-img" src="https://www.local.ch/details/assets/local-ui/local_logo-96b29ea0ed57b9657006a8aa8b4c2dfcf673c2e977cb20df64e7a6e754f162a7.png" srcset="https://www.local.ch/details/assets/local-ui/local_logo@2x-587e3ba4db265aa373c78f37e419342f9eafd63ffd5f61f4c65d986bfd7c9846.png 2x"/>
# </a>
# </div>
# <div class="searchbar-right">
# <form accept-charset="UTF-8" action="https://www.local.ch/en/q?slot=tel" class="lui-display-flex tel search-bar-form hidden-xs" lcl-display-input-icons="" lcl-search-form-ad-slot="rnd" lcl-search-form-url="/details/search_suggestions.json">
# <input autocomplete="off" class="form-control search-bar-what" name="what" placeholder="Who or what?" tabindex="1" title="Who or what?" value=""/>
# <input autocomplete="off" class="form-control search-bar-where" name="where" placeholder="Where?" tabindex="2" title="Where?" value=""/>
# <button class="btn btn-primary search-bar-submit" tabindex="3" title="Find It" type="submit">
# <i class="icon-ios_search_accessory search-bar-button-icon"></i>
# <span class="search-bar-button-text"> Search</span>
# </button>
# <input class="randomizer" name="rid" type="hidden" value="X-BI"/>
# <input name="slot" type="hidden" value="tel"/>
# <div class="js-partial">
# </div>
# <!--[if lt IE 10]>
#   <input name="utf8" type="hidden" value="&#x2713;" autocomplete="off" />
#   <![endif]-->
# </form>
# <div class="bottom-sheet-toggle lui-padding-horizontal-xs lui-display-flex lui-display-flex-center-aligned hidden-sm hidden-md hidden-lg" data-target="search-bar-bottom-sheet" data-toggle="bottom-sheet" type="button">
# <i class="icon-ios_search_accessory bottom-sheet-toggle-icon"></i>
# <div class="bottom-sheet-toggle-placeholder">Who? What? Where?</div>
# </div>
# <!-- Bottom sheet -->
# <div aria-labelledby="search-bar-bottom-sheet-label" class="bottom-sheet bottom-sheet-search-bar" id="search-bar-bottom-sheet" role="dialog" tabindex="-1">
# <div class="bottom-sheet-content bottom-sheet-content-search-bar lui-padding-horizontal-m lui-padding-vertical-m">
# <div class="text-right lui-margin-bottom-m">
# <a aria-label="Close" data-dismiss="bottom-sheet" data-target="search-bar-bottom-sheet">
# <i class="icon-close bottom-sheet-content-search-bar-close"></i>
# </a>
# </div>
# <form accept-charset="UTF-8" action="https://www.local.ch/en/q?slot=tel" class="lui-display-flex tel bottom-sheet-search-bar-form" lcl-display-input-icons="true" lcl-search-form-ad-slot="rnd" lcl-search-form-url="/details/search_suggestions.json">
# <input autocomplete="off" class="form-control search-bar-what bottom-sheet-search-bar-field lui-margin-bottom-m" name="what" placeholder="Who or what?" tabindex="1" title="Who or what?" value=""/>
# <input autocomplete="off" class="form-control search-bar-where bottom-sheet-search-bar-field lui-margin-bottom-m" name="where" placeholder="Where?" tabindex="2" title="Where?" value=""/>
# <button class="btn btn-primary search-bar-submit bottom-sheet-search-bar-submit" tabindex="3" title="Find It" type="submit">
# <i class="icon-ios_search_accessory search-bar-button-icon"></i>
# <span class="search-bar-button-text"> Search</span>
# </button>
# <input class="randomizer" name="rid" type="hidden" value="spWm"/>
# <input name="slot" type="hidden" value="tel"/>
# <div class="js-partial">
# </div>
# <!--[if lt IE 10]>
#   <input name="utf8" type="hidden" value="&#x2713;" autocomplete="off" />
#   <![endif]-->
# </form>
# </div>
# <a aria-label="Close" class="bottom-sheet-close" data-dismiss="bottom-sheet" data-target="search-bar-bottom-sheet"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hero-map-wrapper">
# <div class="hero-map-container" data-lat="47.488027" data-lon="7.731161" id="js-map-container"></div>
# <div class="js-mobile-routing js-gtm-event js-kpi-event hero-map-overlay" data-gtm-json='{"action":"Click","label":"Link Map Banner","category":"Link Map"}' data-kpi-type="map" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-target="#routing" data-toggle="modal"></div>
# <div class="container hero-map-button-wrapper text-right hidden-xs js-mobile-routing" data-target="#routing" data-toggle="modal">
# <button class="hero-map-button btn lui-margin-bottom-l js-gtm-event js-kpi-event" data-gtm-json='{"action":"Click","label":"Link Map","category":"Link Map"}' data-kpi-type="map" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg">
# <span class="icon-listing hero-map-button-icon"></span>
# Show location
# </button>
# </div>
# </div>
# <div class="main-container">
# <div class="container" itemscope="" itemtype="http://schema.org/LocalBusiness">
# <link content="https://www.local.ch/en/d/liestal/4410/hospital/kantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" itemprop="url"/>
# <div class="row">
# <div class="js-sticky-sentinel sticky-sentinel"></div>
# <div class="col-xs-12 js-sticky sticky">
# <div class="row lui-sm-margin-bottom-m">
# <div class="col-xs-12"><div class="js-title-card lui-card title-card lui-display-flex clearfix"><div class="title-card-element-first">
# <div class="lui-display-flex lui-margin-bottom-xs lui-sm-margin-bottom-m title-card-element-first-inner"><div class="js-sticky-hidden title-card-left lui-sm-margin-right-s lui-margin-bottom-xs lui-sm-margin-bottom-zero lui-display-flex">
# <a class="js-gtm-event js-kpi-event logo-link" data-gtm-json='{"action":"Click","label":"Link Website","category":"Link Website","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="url" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.ksbl.ch" rel="nofollow" target="_blank"><div class="title-card-logo-container text-center">
# <img alt="Kantonsspital Baselland Liestal" class="title-card-logo hidden-xs hidden-sm" height="100" itemprop="logo" src="https://images.services.local.ch/bp/logo-ad/fd/fd8c2874683482038a2edaa4c4ee4a3ae73e4e9a/upload1.jpg?center=0.5%2C0.5&amp;scale=fit&amp;size=140x100&amp;v=1&amp;sig=fe0b3e39c3e41c3a223fbeb69f7e1aa7de63e30099cedadfd8bd81cdfc233b65" width="140"/>
# <img alt="Kantonsspital Baselland Liestal" class="title-card-logo hidden-md hidden-lg" height="50" itemprop="logo" src="https://images.services.local.ch/bp/logo-ad/fd/fd8c2874683482038a2edaa4c4ee4a3ae73e4e9a/upload1.jpg?center=0.5%2C0.5&amp;scale=fit&amp;size=70x50&amp;v=1&amp;sig=121994f87b0c9a380b654daedb4c5fe052adea139f1b39710e0f63cd8a4097ef" width="70"/>
# </div>
# </a>
# <div>
# <a class="lui-margin-right-s lui-show-inline-block hidden-print hidden-sm hidden-md hidden-lg js-gtm-event js-kpi-event" data-gtm-json='{"category":"Link vCard","label":"vCard","action":"click"}' data-kpi-type="vcard-export" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="/details/api/places/lAGqVlMCSeL7uV0QLTUWhg/vcard" rel="nofollow">
# <span class="title-card-bookmark-btn-icon icon-add-contact"></span>
# </a>
# <a class="js-bookmark-button lui-show-inline-block hidden-print hidden-sm hidden-md hidden-lg" href="/details/auth/localch?locale=en&amp;origin=https%3A%2F%2Fwww.local.ch%2Fen%2Fd%2Fliestal%2F4410%2Fhospital%2Fkantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" id="js-bookmark-befc"><span class="js-bookmark-icon title-card-bookmark-btn-icon icon-heart-outline"></span>
# </a>
# </div>
# </div><div class="title-card-right">
# <div class="row">
# <div class="col-xs-12">
# <h1 class="lui-margin-vertical-zero title-card-title lui-display-flex lui-display-flex-center-aligned">
# <img alt="Hospital" class="title-card-category-icon lui-margin-right-xs js-sticky-visible hidden" height="22" src="https://bin.staticlocal.ch/localplace-icon/ae/ae0824a1ea4a6d345277f087b87046f90f8d4737/icon-medical.svg" width="22"/>
# <span itemprop="name">Kantonsspital Baselland Liestal</span>
# </h1>
# </div>
# </div>
# <div class="row hidden-sm hidden-md hidden-lg">
# <div class="col-xs-12">
# <a class="js-gtm-event js-sticky-hidden js-scroll-to-feedback js-narrow-scroll-to-feedback feedback-summary-compact-average-rating hidden-sm hidden-md hidden-lg" data-gtm-action="click" data-gtm-category="Link Rating" data-gtm-label="topbutton" href="#feedbacks" rel="nofollow"><span class="hidden-xs">
# <span class="lui-font-bold">3.6</span>
# / 5
# </span>
# <span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="rating-stars-star icon-star-06"></span><span class="icon-star-00 rating-stars-star"></span>
# <span>
# (8 Reviews)
# </span>
# </a>
# </div>
# </div>
# <div class="js-sticky-hidden row">
# <div class="col-xs-12 lui-display-flex title-card-categories-wrapper">
# <img alt="Hospital" class="title-card-category-icon lui-margin-right-xxs lui-margin-top-xxs" height="16" src="https://bin.staticlocal.ch/localplace-icon/ae/ae0824a1ea4a6d345277f087b87046f90f8d4737/icon-medical.svg" width="16"/>
# <span class="title-card-categories"><span class="title-card-category">Hospital</span><span class="title-card-category">Emergency services</span><span class="title-card-category">Clinic</span></span>
# </div>
# </div>
# <div class="js-sticky-hidden">
# <div class="row">
# <div class="col-xs-12 title-card-subtitle">Empfang / Anmeldung</div>
# </div>
# </div>
# <div class="js-sticky-hidden row">
# <div class="col-xs-12 small">
# <span class="hidden-print text-success opening-hours-status">Open</span>
# <span class="opening-hours-status-separator">
# ·
# </span>
# <span class="opening-hours-status-until">
# All day
# </span>
# </div>
# </div>
# </div></div>
# <div class="row hidden-print">
# <div class="col-xs-12">
# <div class="title-card-actions lui-display-flex">
# <a class="js-gtm-event js-kpi-event btn title-card-actions-link lui-margin-right-m btn-primary" data-gtm-json='{"action":"Click","label":"Default","category":"Phone Number","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="call" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay="" href="tel:+41619252525" id="js-contact-57ce">
# <span class="title-card-actions-icon icon-phone"></span><span class="js-btn-label js-kpi-event lui-margin-left-xxs" data-gtm-json='{"action":"Phone Number","label":"DetailEntry","category":"Default - Hidden","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="show_hidden_number" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay-label="Call 061 925 25 25">
# 061...Show number
# </span>
# </a>
# <a class="title-card-actions-link lui-sm-margin-right-m btn js-gtm-event js-kpi-event hidden-xs hidden-sm hidden-md" data-gtm-json='{"action":"Click","label":"Link Website","category":"Link Website","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="url" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.ksbl.ch" target="_blank">
# <span class="title-card-actions-icon icon-website"></span>
# <span class="lui-sm-margin-left-xxs">Website</span>
# </a>
# <a class="title-card-actions-link lui-sm-margin-right-m btn js-gtm-event js-kpi-event hidden-xs hidden-sm hidden-md" data-gtm-json='{"action":"Click","label":"E-Mail","category":"E-Mail","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="email" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="mailto:info@ksbl.ch" target="">
# <span class="title-card-actions-icon icon-envelope"></span>
# <span class="lui-sm-margin-left-xxs">E-mail</span>
# </a>
# <div class="dropdown hidden-xs">
# <a aria-expanded="true" aria-haspopup="true" class="js-gtm-event title-card-actions-link btn dropdown-toggle" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link More" data-gtm-label="Link More" data-toggle="dropdown" href="#" rel="nofollow" role="button">
# <span class="icon-dots title-card-actions-icon"></span>
# <span class="lui-sm-margin-left-xxs">More</span>
# </a>
# <ul class="dropdown-menu" role="menu">
# <li>
# <a class="js-gtm-event js-kpi-event hidden-lg" data-gtm-json='{"action":"Click","label":"Link Website","category":"Link Website","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="url" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.ksbl.ch" rel="" target="_blank">Website</a>
# </li>
# <li>
# <a class="js-gtm-event js-kpi-event hidden-lg" data-gtm-json='{"action":"Click","label":"E-Mail","category":"E-Mail","CTAPlacement":"DetailEntry-StickyCTA"}' data-kpi-type="email" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="mailto:info@ksbl.ch" rel="" target="">E-mail</a>
# </li>
# <li>
# <a class="js-gtm-event" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Edit Entry Link" data-gtm-label="localsearch" href="https://my.localsearch.ch/profiles?place_id=lAGqVlMCSeL7uV0QLTUWhg&amp;locale=en" rel="nofollow" target="_blank">Edit entry</a>
# </li>
# <li>
# <a class="js-gtm-event" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link More" data-gtm-label="manage presence" href="https://my.localsearch.ch?locale=en&amp;place_id=lAGqVlMCSeL7uV0QLTUWhg" rel="nofollow" target="_blank">Manage presence</a>
# </li>
# <li>
# <a class="js-gtm-event" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link More" data-gtm-label="QR code download" href="https://ratings.services.local.ch/en/entries/lAGqVlMCSeL7uV0QLTUWhg/qrcode" rel="nofollow" target="_blank">QR code for customer ratings</a>
# </li>
# <li>
# <a class="js-gtm-event js-kpi-event" data-gtm-json='{"category":"Link vCard","label":"vCard","action":"click"}' data-kpi-type="vcard-export" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="/details/api/places/lAGqVlMCSeL7uV0QLTUWhg/vcard" rel="" target="">Save the address (vCard)</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="title-card-element-line hidden-xs lui-margin-left-m"></div><div class="title-card-element-fixed lui-display-flex lui-padding-left-m hidden-xs">
# <div class="btn-group" role="group">
# <a class="js-gtm-event js-kpi-event title-card-actions-link title-card-actions-link-group btn hidden-xs" data-gtm-json='{"category":"Link Print","label":"With Map","action":"lAGqVlMCSeL7uV0QLTUWhg"}' data-kpi-type="print" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="javascript:window.print();" rel="nofollow">
# <span class="icon-print title-card-actions-icon"></span>
# </a>
# <a class="js-bookmark-button btn hidden-print title-card-actions-link title-card-actions-link-group" href="/details/auth/localch?locale=en&amp;origin=https%3A%2F%2Fwww.local.ch%2Fen%2Fd%2Fliestal%2F4410%2Fhospital%2Fkantonsspital-baselland-liestal-lAGqVlMCSeL7uV0QLTUWhg" id="js-bookmark-14a4"><span class="js-bookmark-icon title-card-actions-icon icon-heart-outline"></span>
# </a>
# </div>
# <a class="js-gtm-event js-scroll-to-feedback feedback-summary-average-rating text-center" data-gtm-action="click" data-gtm-category="Link Rating" data-gtm-label="topbutton" href="#feedbacks" rel="nofollow"><div class="feedback-summary-ratings-value lui-margin-bottom-xxs">
# <span class="js-sticky-visible feedback-summary-icon-star icon-star-10 rating-stars-star hidden"></span>
# <span class="feedback-summary-ratings-average lui-font-bold">3.6</span>
# / 5
# </div>
# <div class="js-sticky-hidden feedback-summary-ratings-stars">
# <span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="rating-stars-star icon-star-06"></span><span class="icon-star-00 rating-stars-star"></span>
# </div>
# <span class="js-sticky-hidden">
# (8)
# </span>
# </a>
# </div></div></div>
# </div>
# </div>
# <div class="col-xs-12">
# <div class="row lui-sm-margin-bottom-m hidden-print">
# <div class="col-xs-12 text-center lui-padding-horizontal-zero lui-sm-padding-horizontal-s">
# <img alt="Kantonsspital Baselland Liestal" class="image hidden-sm hidden-md hidden-lg" itemprop="image" src="https://images.services.local.ch/bp/localplace-images/07/0736f3cfdcbaa5a06ead33c23f8a5b2e20b9f3dc/27337273_1635284933183775_3269359626804952435_n.jpg?center=0.500000%2C0.549057&amp;scale=crop&amp;size=768x198&amp;v=1&amp;sig=bf47c41636bf125285bff501e973bea1725dcf80e0a2235a0755a9f532762bd6"/>
# <img alt="Kantonsspital Baselland Liestal" class="image hidden-xs" itemprop="image" src="https://images.services.local.ch/bp/localplace-images/07/0736f3cfdcbaa5a06ead33c23f8a5b2e20b9f3dc/27337273_1635284933183775_3269359626804952435_n.jpg?center=0.500000%2C0.549057&amp;scale=crop&amp;size=1170x300&amp;v=1&amp;sig=6415e33bceed4634e6aa5cecf4ca4b858c881ef71a2b03ce5a42b3e2200955f8"/>
# </div>
# </div>
# <div class="lui-card lui-sm-margin-bottom-m hidden-print tiny-gallery-lui-card">
# <div class="lui-card-body">
# <div class="row">
# <div class="col-xs-12 lui-padding-horizontal-zero lui-sm-padding-horizontal-s">
# <div class="tiny-gallery" id="js-tiny-gallery-c705">
# <div class="js-tiny-gallery-slider-left tiny-gallery-slider tiny-gallery-slider-left hidden-xs hidden">
# <span class="tiny-gallery-slider-icon icon-chevron-left-bold"></span>
# </div>
# <div class="js-tiny-gallery-slider-right tiny-gallery-slider tiny-gallery-slider-right hidden-xs hidden">
# <span class="tiny-gallery-slider-icon icon-chevron-right-bold"></span>
# </div>
# <div class="tiny-gallery-container">
# <div class="tiny-gallery-wrapper-scroll">
# <div class="js-tiny-gallery-wrapper tiny-gallery-wrapper">
# <a class="tiny-gallery-link js-gtm-event" data-gtm-action="click" data-gtm-category="Tiny Pictures" data-gtm-label="Pictures 1" href="https://bin.staticlocal.ch/info-image-ad/e3/e3b00ae7e9e33327d0108bed0339068a326ff719/data.jpg" rel="gallery"><img alt="Kantonsspital Baselland Liestal" class="tiny-gallery-thumbnail" height="110" src="https://images.services.local.ch/bp/info-image-ad/e3/e3b00ae7e9e33327d0108bed0339068a326ff719/data.jpg?scale=crop&amp;size=110x110&amp;smartcrop=1&amp;v=1&amp;sig=5c4f29061b5beb1ffea2c81d5d877f98892d673444b24468f5b9a3b096cbe47d" srcset="https://images.services.local.ch/bp/info-image-ad/e3/e3b00ae7e9e33327d0108bed0339068a326ff719/data.jpg?dpr=1&amp;scale=crop&amp;size=220x220&amp;smartcrop=1&amp;v=1&amp;sig=49798ea010965bdba1ea11e97850b96b8a2d9285427aa0b58e245f316363feb2 2x" width="110">
# </img></a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-12">
# <div class="row split-columns-container">
# <div class="columns-left col-xs-12 col-sm-6 col-md-8 split-column">
# <div class="hidden-sm hidden-md hidden-lg">
# <div class="row lui-sm-margin-bottom-m">
# <div class="col-xs-12">
# <div class="opening-hours lui-card">
# <div class="lui-card-header clearfix">
# <h3 class="opening-hours-title lui-margin-vertical-zero pull-left">
# <span class="icon-asset-openinghours visible-xs-inline"></span>
# Opening Hours
# </h3>
# <span class="pull-right hidden-xs">
# <span class="hidden-print text-success opening-hours-status">Open</span>
# <span class="opening-hours-status-separator">
# ·
# </span>
# <span class="opening-hours-status-until">
# All day
# </span>
# </span>
# </div>
# <div class="lui-card-body opening-hours-body">
# <div class="row">
# <div class="col-xs-12">
# <div class="row hidden-print visible-xs">
# <div class="col-xs-12">
# <a class="opening-hours-link text-right lui-padding-bottom-xs" data-target="#js-opening-hours-full-cb0e-content,#js-opening-hours-full-cb0e-today-opening-hours-row" href="javascript:void(0);" id="js-opening-hours-full-cb0e-link">
# <span>
# <span class="hidden-print text-success opening-hours-status">Open</span>
# <span class="opening-hours-status-separator">
# ·
# </span>
# <span class="opening-hours-status-until">
# All day
# </span>
# </span>
# <span class="opening-hours-link-icon icon-chevron-down"></span>
# </a>
# </div>
# </div>
# <div class="opening-hours-times-block row" id="js-opening-hours-full-cb0e-content" style="display:none;">
# <div class="col-xs-12">
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Monday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row lui-font-bold">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Tuesday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Wednesday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Thursday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Friday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Saturday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Sunday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row lui-margin-bottom-xs lui-sm-margin-bottom-m full-height">
# <div class="col-xs-12 full-height"><div class="lui-card contact-card full-height">
# <div class="lui-card-header">
# <h3 class="lui-margin-vertical-zero hidden-xs">Contacts &amp; location</h3>
# </div>
# <div class="lui-card-body contact-card-container">
# <div class="row">
# <div class="col-xs-12 col-md-6 col-md-push-6" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <div class="row address-title">
# <div class="col-xs-12">
# <span class="icon-listing"></span>
# Address
# </div>
# </div>
# <div class="address-container lui-margin-bottom-s">
# <div class="js-routing-modal js-gtm-event js-kpi-event address-lines js-mobile-routing" data-gtm-json='{"category":"Link Address","label":"Link Address","action":"Click"}' data-kpi-type="address" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-target="#routing" data-toggle="modal">
# <div class="row">
# <div class="col-xs-12"><span itemprop="streetAddress">Rheinstrasse 26</span></div>
# </div>
# <div class="row">
# <div class="col-xs-12"><span itemprop="postalCode">4410</span> <span itemprop="addressLocality">Liestal</span></div>
# </div>
# </div>
# </div>
# <button class="js-gtm-event js-kpi-event js-routing-modal btn direction-btn hidden-xs hidden-sm" data-gtm-json='{"category":"Link Routing","label":"Driving","action":"click"}' data-kpi-type="address" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-target="#routing" data-toggle="modal">
# <span class="icon-route direction-btn-icon"></span>
# <span class="lui-margin-left-xxs">
# Get directions
# </span>
# </button>
# </div>
# <div class="col-xs-12 col-md-6 col-md-pull-6">
# <div class="contact-container">
# <div class="row contact-title">
# <div class="col-xs-12">
# <span class="icon-phone"></span>
# Empfang
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12">
# <meta content="061 925 25 25" itemprop="telephone"/>
# <span class="js-copy-to-clipboard contact-card-overlay hidden-print js-contact-overlay js-gtm-event js-kpi-event" data-gtm-json='{"action":"lAGqVlMCSeL7uV0QLTUWhg","label":"Default","category":"Phone Number","CTAPlacement":"DetailEntry"}' data-kpi-type="call" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay="">
# <span class="js-btn-label" data-gtm-json='{"action":"Phone Number","label":"DetailEntry","category":"Default - Hidden","CTAPlacement":"DetailEntry"}' data-kpi-type="show_hidden_number" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay-label="061 925 25 25">061...Show number</span>
# </span>
# <span class="visible-print-inline">061 925 25 25</span>
# </div>
# </div>
# </div>
# <div class="contact-container">
# <div class="row contact-title">
# <div class="col-xs-12">
# <span class="icon-phone"></span>
# Fax
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12">
# <meta content="061 925 20 90" itemprop="faxNumber"/>
# <span class="contact-card-advertising-star"></span><span class="js-copy-to-clipboard contact-card-overlay hidden-print js-contact-overlay js-gtm-event js-kpi-event" data-gtm-json='{"action":"lAGqVlMCSeL7uV0QLTUWhg","label":"Default","category":"Fax Number","CTAPlacement":"DetailEntry"}' data-kpi-type="call" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay="">
# <span class="js-btn-label" data-gtm-json='{"action":"Fax Number","label":"DetailEntry","category":"Default - Hidden","CTAPlacement":"DetailEntry"}' data-kpi-type="show_hidden_number" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay-label="061 925 20 90">061...Show number</span>
# </span>
# <span class="visible-print-inline">061 925 20 90</span>
# </div>
# </div>
# </div>
# <div class="contact-container">
# <div class="row contact-title">
# <div class="col-xs-12">
# <span class="icon-phone"></span>
# Sanitätsnotruf (Notruf für Unfälle und Notfälle)
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12">
# <meta content="144" itemprop="telephone"/>
# <span class="contact-card-advertising-star"></span><span class="js-copy-to-clipboard contact-card-overlay hidden-print js-contact-overlay js-gtm-event js-kpi-event" data-gtm-json='{"action":"lAGqVlMCSeL7uV0QLTUWhg","label":"Default","category":"Phone Number","CTAPlacement":"DetailEntry"}' data-kpi-type="call" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay="">
# <span class="js-btn-label" data-gtm-json='{"action":"Phone Number","label":"DetailEntry","category":"Default - Hidden","CTAPlacement":"DetailEntry"}' data-kpi-type="show_hidden_number" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" data-overlay-label="144">144...Show number</span>
# </span>
# <span class="visible-print-inline">144</span>
# </div>
# </div>
# </div>
# <div class="contact-container">
# <div class="row contact-title">
# <div class="col-xs-12">
# <span class="icon-envelope"></span>
# Email
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12">
# <meta content="info@ksbl.ch" itemprop="email"/>
# <a class="contact-card-link js-gtm-event js-kpi-event" data-gtm-json='{"action":"lAGqVlMCSeL7uV0QLTUWhg","label":"E-Mail","category":"E-Mail","CTAPlacement":"DetailEntry"}' data-kpi-type="email" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="mailto:info@ksbl.ch" target="">
# info@ksbl.ch
# </a>
# </div>
# </div>
# </div>
# <div class="contact-container">
# <div class="row contact-title">
# <div class="col-xs-12 hidden-xs">
# <span class="icon-website"></span>
# Website
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12 lui-text-overflow">
# <meta content="www.ksbl.ch" itemprop="url"/>
# <a class="contact-card-link contact-card-website_link js-gtm-event js-kpi-event" data-gtm-json='{"action":"lAGqVlMCSeL7uV0QLTUWhg","label":"www.ksbl.ch","category":"Link Website","CTAPlacement":"DetailEntry"}' data-kpi-type="url" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.ksbl.ch" target="_blank">
# <span class="hidden-md hidden-lg hidden-sm icon-website">
# Website
# </span>
# <span class="hidden-xs">
# www.ksbl.ch
# </span>
# </a>
# </div>
# </div>
# </div>
# <div class="lui-margin-top-xs hidden-print social-media-container lui-padding-bottom-s">
# <div class="row">
# <div class="col-xs-12 social-media-title">
# <span class="icon-people-alt"></span>
# Social Media
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12 lui-margin-top-xs">
# <a class="js-gtm-event js-kpi-event social-media-link text-center lui-margin-right-xs" data-gtm-json='{"category":"Link Social","action":"lAGqVlMCSeL7uV0QLTUWhg","label":"facebook"}' data-kpi-type="social_media" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.facebook.com/ksbl.ch" rel="nofollow" target="_blank"><span class="social-media-icon icon-facebook"></span>
# </a><a class="js-gtm-event js-kpi-event social-media-link text-center lui-margin-right-xs" data-gtm-json='{"category":"Link Social","action":"lAGqVlMCSeL7uV0QLTUWhg","label":"linked_in"}' data-kpi-type="social_media" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.linkedin.com/company/kantonsspital-baselland" rel="nofollow" target="_blank"><span class="social-media-icon icon-linked_in"></span>
# </a><a class="js-gtm-event js-kpi-event social-media-link text-center lui-margin-right-xs" data-gtm-json='{"category":"Link Social","action":"lAGqVlMCSeL7uV0QLTUWhg","label":"xing"}' data-kpi-type="social_media" data-kpi-uid="lAGqVlMCSeL7uV0QLTUWhg" href="https://www.xing.com/companies/kantonsspitalbaselland" rel="nofollow" target="_blank"><span class="social-media-icon icon-xing"></span>
# </a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="row lui-margin-top-xxs">
# <div class="col-xs-12">
# <span class="contact-card-advertising-hint small">
# No advertising material
# </span>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# <div class="columns-right col-xs-12 col-sm-6 col-md-4 split-column">
# <div class="hidden-xs hidden-print">
# <div class="row lui-sm-margin-bottom-m">
# <div class="col-xs-12">
# <div class="opening-hours lui-card">
# <div class="lui-card-header clearfix">
# <h3 class="opening-hours-title lui-margin-vertical-zero pull-left">
# <span class="icon-asset-openinghours visible-xs-inline"></span>
# Opening Hours
# </h3>
# <span class="pull-right hidden-xs">
# <span class="hidden-print text-success opening-hours-status">Open</span>
# <span class="opening-hours-status-separator">
# ·
# </span>
# <span class="opening-hours-status-until">
# All day
# </span>
# </span>
# </div>
# <div class="lui-card-body opening-hours-body">
# <div class="row">
# <div class="col-xs-12">
# <div class="row hidden-print visible-xs">
# <div class="col-xs-12">
# <a class="opening-hours-link text-right lui-padding-bottom-xs" data-target="#js-opening-hours-full-3cff-content,#js-opening-hours-full-3cff-today-opening-hours-row" href="javascript:void(0);" id="js-opening-hours-full-3cff-link">
# <span>
# <span class="hidden-print text-success opening-hours-status">Open</span>
# <span class="opening-hours-status-separator">
# ·
# </span>
# <span class="opening-hours-status-until">
# All day
# </span>
# </span>
# <span class="opening-hours-link-icon icon-chevron-down"></span>
# </a>
# </div>
# </div>
# <div class="opening-hours-times-block row" id="js-opening-hours-full-3cff-content" style="display:none;">
# <div class="col-xs-12">
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Monday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row lui-font-bold">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Tuesday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Wednesday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Thursday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Friday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Saturday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# <div class="opening-hours-row">
# <div class="row">
# <div class="col-xs-12 opening-hours-information">
# Sunday
# <div class="text-right">
# <p class="lui-margin-bottom-zero">Open all day</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="columns-bottom col-xs-12 col-md-8">
# <div class="row lui-margin-bottom-xs lui-sm-margin-bottom-m hidden-print">
# <div class="col-xs-12">
# <div class="lui-card">
# <div class="lui-card-header">
# <h3 class="lui-margin-vertical-zero">Overview</h3>
# </div>
# <div class="lui-card-body">
# <div class="row lui-margin-vertical-s">
# <div class="col-xs-2 col-sm-1 text-right">
# <img alt="Location" height="24" src="/details/assets/attributes/general_geo-93755e05f4162eace5fa8c8e7e741799bfd3b8a88f27f27c1955ac2366eaaf91.svg" width="24">
# </img></div>
# <div class="col-xs-10 col-sm-11">
# <div class="row">
# <div class="col-xs-12">
# <strong class="small">Location</strong>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12 lui-margin-top-xxs small">Close to public transport, Parking site</div>
# </div>
# </div>
# </div>
# <div class="row lui-margin-vertical-s">
# <div class="col-xs-12">
# <div class="row">
# <div class="col-xs-12">
# <strong class="small">Organization</strong>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12 lui-margin-top-xxs small">Kantonsspital Baselland Liestal</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade js-mobile-routing-gtm" id="routing" role="dialog" tabindex="-1">
# <div class="modal-dialog routing-modal-dialog" role="document">
# <div class="modal-content routing-modal-content">
# <button class="js-routing-close modal-close-routing" data-dismiss="modal" type="button">
# <i class="icon-close routing-icon-close"></i>
# </button>
# <div class="row">
# <div class="col-xs-12">
# <div class="routing-container-toolbar js-routing" id="js-routing-bd66">
# <form accept-charset="UTF-8" action="#" class="js-routing-form" method="post"><input autocomplete="off" name="utf8" type="hidden" value="✓"><input autocomplete="off" name="authenticity_token" type="hidden" value="0EXBdCl6M7dm29iw8SBN9x4WKn9pAYFeJ3DrOSL+1zNfRa4OuTx5/hzMKSdxHKhRRf+eU4qhgPhYEtkfJprrJg=="><div class="row lui-margin-bottom-xs">
# <div class="col-xs-12">
# <div class="routing-container">
# <div class="btn-group routing-btn-group">
# <label class="js-routing-btn js-current-position routing-btn routing-btn-active btn btn-default">
# <input class="hidden" id="travelMode_car" name="travelMode" type="radio" value="car">
# <span class="icon-listing"></span>
# </input></label>
# <label class="js-routing-btn js-routing-mode-btn routing-btn btn btn-default" data-mode="oev">
# <input class="js-routing-mode-input js-gtm-event hidden" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link Routing" data-gtm-label="Oev" data-mode="oev" id="travelMode_oev" name="travelMode" type="radio" value="oev">
# <span class="icon-metro"></span>
# </input></label>
# <label class="js-routing-btn js-routing-mode-btn routing-btn btn btn-default" data-mode="car">
# <input class="js-routing-mode-input js-gtm-event hidden" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link Routing" data-gtm-label="Car" data-mode="car" id="travelMode_car" name="travelMode" type="radio" value="car">
# <span class="icon-car"></span>
# </input></label>
# <label class="js-routing-btn js-routing-mode-btn routing-btn btn btn-default" data-mode="bicycle">
# <input class="js-routing-mode-input js-gtm-event hidden" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link Routing" data-gtm-label="Bicycle" data-mode="bicycle" id="travelMode_bicycle" name="travelMode" type="radio" value="bicycle">
# <span class="icon-cyclist"></span>
# </input></label>
# <label class="js-routing-btn js-routing-mode-btn routing-btn btn btn-default" data-mode="pedestrian">
# <input class="js-routing-mode-input js-gtm-event hidden" data-gtm-action="lAGqVlMCSeL7uV0QLTUWhg" data-gtm-category="Link Routing" data-gtm-label="Pedestrian" data-mode="pedestrian" id="travelMode_pedestrian" name="travelMode" type="radio" value="pedestrian">
# <span class="icon-pedestrian"></span>
# </input></label>
# </div>
# <div class="routing-inputs-container">
# <div class="routing-inputs-sub-group">
# <div class="routing-input-with-addon">
# <div class="input-group-addon routing-widget-addon">From</div>
# <div class="routing-input-with-icon">
# <i class="icon-find-me routing-input-find-me-icon js-locate-me" data-url="/details/api/address/lookup"></i>
# <input class="form-control js-routing-from-input js-routing-form-input-locate-me routing-form-input-with-icon" id="from" name="from" type="text" value="">
# </input></div>
# </div>
# <div class="js-routing-swap btn btn-default routing-swap-btn">
# <span class="icon-directions routing-icon-directions"></span>
# </div>
# </div>
# <div class="routing-inputs-sub-group">
# <div class="routing-input-with-addon">
# <div class="input-group-addon routing-widget-addon">To</div>
# <div class="routing-input-with-icon">
# <span class="icon-find-me routing-input-find-me-icon js-locate-me hidden" data-url="/details/api/address/lookup"></span>
# <input class="form-control js-routing-to-input routing-form-input-with-icon routing-form-input-with-hidden-icon" id="to" name="to" type="text" value="Rheinstrasse 26, 4410 Liestal"/>
# </div>
# </div>
# <div class="input-group">
# <button class="js-routing-find btn btn-primary routing-find-btn" role="button" type="submit">
# <i class="icon-ios_search_accessory search-bar-button-icon"></i>
# </button>
# </div>
# </div>
# <input autocomplete="off" class="js-routing-coords-input" disabled="disabled" id="coords_from" name="coords_from" type="hidden" value="47.488027,7.731161"/>
# <input autocomplete="off" class="js-routing-coords-input" id="coords_to" name="coords_to" type="hidden" value="47.488027,7.731161"/>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12">
# <div class="routing-info-container">
# <div class="js-routing-data hidden">
# <span class="icon-time hidden-md hidden-lg"></span>
# <strong class="hidden-xs hidden-sm">
# Duration:
# </strong>
# <span class="js-routing-duration"></span>
# <span class="icon-listing hidden-md hidden-lg"></span>
# <strong class="hidden-xs hidden-sm">
# Distance:
# </strong>
# <span class="js-routing-distance"></span>
# </div>
# <div class="routing-links">
# <a class="js-routing-show-route-link routing-show-route-link hidden" href="//map.search.ch/"><i class="icon-route routing-link-icon"></i>Show route
# </a></div>
# </div>
# </div>
# </div>
# </input></input></form></div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12">
# <div class="row" itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
# <meta content="47.488027" itemprop="latitude"/>
# <meta content="7.731161" itemprop="longitude"/>
# <div class="col-xs-12">
# <div class="js-map map" data-marker="https://www.local.ch/details/assets/maps-marker-01217da72a921a15117a2a3e3c01ae2343b2341908a7501302d0cbc6f70cb9ae.svg" data-position="[47.488027,7.731161]" id="js-routing-map-4059">
# <div class="routing-error-message lui-margin-top-s alert alert-warning js-locate-me-error hidden" role="alert">
# <strong>Position cannot be determined.</strong>
# <span aria-label="Close" class="routing-error-message-close lui-margin-left-xs js-routing-error-message-close">×</span>
# </div>
# <div class="js-map-container map-container"></div>
# <div class="js-loading-overlay loading-overlay hidden">
# <div class="loading-spinner-container">
# <i class="icon-spinner-alt routing-spinner spinning"></i>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="description lui-card lui-margin-bottom-xs lui-sm-margin-bottom-m hidden-print">
# <div class="lui-card-header">
# <h3 class="lui-margin-vertical-zero">Kantonsspital Baselland Liestal</h3>
# </div>
# <div class="lui-card-body">
# <div class="row">
# <div class="col-xs-12 description-content" data-less="less" data-more="read more" id="js-description-bbbc" itemprop="description">
# <p><i>The mission of the Kantonsspital Baselland (Canton Hospital of Basel-Country - KSBL) is to provide medical services to about one quarter of a million individuals. At the same time, the hospital is actively engaged in basic and advanced medical training programs. </i></p>
# <p><i><i>Through our clinics and institutions at three locations we offer the full spectrum of first rate medical services at what we refer to as a central hospital organization. In some instances we are purposefully consolidating the expertise of specific medical fields at one single location. Thanks to this model we are currently in a position to offer patients in Basel and vicinity all of the vast services of a large hospital while simultaneously bundling medical knowledge at clinics with specific professional focal points. Given that we operate our own university clinics and institutions, engage in research collaborations with other universities and integrated research projects with healthcare/life science enterprises, we are ideally positioned to offer our patients ultra-modern medical services and technologies. </i></i></p>
# </div>
# </div>
# </div>
# </div>
# <div class="js-feedbacks-container row lui-margin-bottom-xs lui-sm-margin-bottom-m hidden-print" id="feedbacks">
# <div class="col-xs-12">
# <div class="lui-card">
# <div class="lui-card-body">
# <div class="row">
# <div class="col-xs-12"><div class="js-async-renderer" data-entry-id="lAGqVlMCSeL7uV0QLTUWhg" data-error-message="There was a problem loading customer feedbacks. Please try again later." data-placeholder=".js-feedback-placeholder-lAGqVlMCSeL7uV0QLTUWhg" data-url="/details/local_feedback/feedback"></div>
# <div class="placeholder lui-loading js-feedback-placeholder-lAGqVlMCSeL7uV0QLTUWhg"></div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12">
# <h3 class="lui-margin-top-zero lui-margin-bottom-xs">What visitors say about Kantonsspital Baselland Liestal</h3>
# </div>
# </div>
# <div class="lui-margin-bottom-xs" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <div class="hidden" itemprop="author" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="local.ch" itemprop="name"/>
# <link href="https://www.local.ch" itemprop="url"/>
# </div>
# <meta content="1" itemprop="worstRating"/>
# <meta content="3" itemprop="reviewCount"/>
# <meta content="8" itemprop="ratingCount"/>
# <div class="lui-display-flex lui-display-flex-center-aligned">
# <div class="feedback-summary-stars lui-margin-right-xs"><span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="icon-star-10 rating-stars-star"></span><span class="rating-stars-star icon-star-06"></span><span class="icon-star-00 rating-stars-star"></span></div>
# <div class="text-muted text-nowrap">
# <span class="lui-font-bold color-gray-primary" itemprop="ratingValue">3.6</span>
# <meta content="5" itemprop="bestRating"/>
# </div>
# </div>
# <div class="text-muted text-nowrap lui-margin-top-xs">
# 8 ratings
# | 3 reviews
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12"><div class="js-async-renderer" data-entry-id="lAGqVlMCSeL7uV0QLTUWhg" data-error-message="There was a problem loading customer feedbacks. Please try again later." data-placeholder=".js-feedbacks-placeholder-lAGqVlMCSeL7uV0QLTUWhg" data-url="/details/local_feedback/feedbacks"></div>
# <div class="placeholder lui-loading js-feedbacks-placeholder-lAGqVlMCSeL7uV0QLTUWhg"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row lui-margin-bottom-xs lui-sm-margin-bottom-m">
# <div class="col-xs-12"><div class="lui-card">
# <div class="lui-card-header categories-links-card-header">
# <h3 class="lui-margin-vertical-zero">Related categories</h3>
# <a class="categories-links-collapsible-link text-right" data-target="#js-categories-links-44e7-content" href="javascript:void(0);" id="js-categories-links-44e7-link">
# <span class="categories-links-collapsible-link-icon icon-chevron-down"></span>
# </a>
# </div>
# <div class="lui-card-body categories-links-content-block lui-margin-top-s" id="js-categories-links-44e7-content" style="display: none;">
# <div class="row">
# <div class="col-xs-12"><a class="categories-links-category" href="https://www.local.ch/en/q/switzerland/hospital?slot=yellow">Hospital</a><a class="categories-links-category" href="https://www.local.ch/en/q/switzerland/emergency%20services?slot=yellow">Emergency services</a><a class="categories-links-category" href="https://www.local.ch/en/q/switzerland/clinic?slot=yellow">Clinic</a></div>
# </div>
# </div>
# </div></div>
# </div>
# <div class="row lui-margin-bottom-s">
# <div class="col-xs-12">
# <span class="small source-label">
# Source:
# Swisscom Directories AG
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden-print">
# <div class="footer">
# <div class="lui-padding-top-l lui-padding-bottom-l">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-md-4">
# <h3 class="footer-header">Directories</h3>
# <ul class="footer-list">
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.local.ch/en/tel" target="_top">Phone Book</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.local.ch/en/yellow" target="_top">Yellow Pages</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.local.ch/en/tel/phone-number-search" target="_top">Phone Number Search</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.local.ch/en/tel/emergency" target="_top">Emergency Phone Numbers</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://info.local.ch/en/our-services" target="_top">Print</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://info.local.ch/en/our-services" target="_top">Mobile &amp; Online</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.localcities.ch/en/" target="_top">Localcities Municipalities</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.localcities.ch/yourclub" target="_top">Localcities Clubs</a>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-4">
# <h3 class="footer-header"><a class="footer-link" href="https://www.localsearch.ch/en/our-sme-solutions" target="_top">Our SME Solutions</a></h3>
# <ul class="footer-list">
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/digitalone/" target="_top">The success package for your SME</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/digitalplus/" target="_top">Advertise where it really counts</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/mywebsite/" target="_top">The professional website at a fixed price</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/mycockpit/" target="_top">Digital appointment and customer management</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/mylocalina/" target="_top">Reservation tool for restaurants</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://localsearch.ch/en/mycommerce/" target="_top">The all-in-one e-commerce solution</a>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-4">
# <h3 class="footer-header"><a class="footer-link" href="http://info.local.ch/en/your-listing" target="_top">Your listing</a></h3>
# <ul class="footer-list">
# <li class="footer-list-item">
# <a class="footer-link" href="https://info.local.ch/en/contact/contact-form-business-customer" target="_top">Create / change / delete company entry</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://info.local.ch/en/contact/contact-private-customer" target="_top">Create / change / delete private entry</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://www.local.ch/en/advertising-calls" target="_top">Telemarketing</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="https://privacyportal-eu-cdn.onetrust.com/dsarwebform/b9865779-0248-4bd3-86ae-adcc74e59b6c/03029c5e-bf5a-4477-b315-b9b11d80d9ee.html" target="_top">Rights of data subjects</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-md-4">
# <h3 class="footer-header">Customer service</h3>
# <ul class="footer-list">
# <li class="footer-list-item">
# <a class="footer-link" href="http://info.local.ch/en/medien/kontakt" rel="nofollow" target="_top">Contact local.ch</a>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-4">
# <h3 class="footer-header"><a class="footer-link" href="http://info.local.ch/en/medien" target="_top">Media</a></h3>
# <ul class="footer-list">
# <li class="footer-list-item">
# <a class="footer-link" href="http://info.local.ch/en/medien/medienmitteilungen" target="_top">Media information</a>
# </li>
# <li class="footer-list-item">
# <a class="footer-link" href="http://info.local.ch/en/medien/local-dot-ch-in-den-medien" target="_top">local.ch in the media</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom">
# <div class="container">
# <div class="row lui-padding-top-m">
# <div class="col-sm-9">
# <small class="lui-margin-bottom-xs">
# <a class="footer-link" href="https://localsearch.ch/en/legal-notice/" target="_top">Legal notice</a>
# |
# <a class="footer-link" href="https://localsearch.ch/en/terms-and-conditions-of-use/" target="_top">Terms and conditions of use</a>
# |
# <a class="footer-link" href="https://localsearch.ch/en/general-terms-and-conditions/" target="_top">General Terms and Conditions (GT &amp; C) and product descriptions</a>
# |
# <a class="footer-link" href="https://localsearch.ch/en/privacy-statement/" target="_top">Privacy statement</a>
# |
# <a class="footer-link" href="https://www.local.ch/en/cookiepolicy" target="_top">Cookie policy</a>
# |
# <a class="footer-link" href="https://localsearch.ch/en/advertising-guidelines/" target="_top">Advertising Guidelines</a>
# </small>
# </div>
# <div class="col-sm-3">
# <div class="clearfix">
# <ul class="footer-sozial-media list-inline lui-margin-bottom-m">
# <li>
# <a class="footer-social-media-link" href="http://www.facebook.com/localch" rel="nofollow" target="_top"><i class="icon-facebook"></i>
# </a></li>
# <li>
# <a class="footer-social-media-link" href="http://twitter.com/localch" rel="nofollow" target="_top"><i class="icon-twitter"></i>
# </a></li>
# <li>
# <a class="footer-social-media-link" href="https://www.instagram.com/local_ch/" rel="publisher" target="_top"><i class="icon-instagram"></i>
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script crossorigin="anonymous" integrity="sha256-CSXorXvZcTkaix6Yvo6HppcZGetbYMGWSFlBw8HfCJo=" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <script src="https://bin.staticlocal.ch/local-ui/29.3.0/javascripts/local-ui.min.js"></script>
# <script src="https://map.search.ch/api/map.js?lang=en"></script>
# <script src="/details/assets/application-b6b6cb9647370d2ec3f1b30b937e88906415725c290db3da50f1044628db7b06.js"></script>
# <script>
#   window.reportVisit('lAGqVlMCSeL7uV0QLTUWhg', 'https://a.local.ch');
#   window.jQuery(function ($) {
#     window.stickyHeader($('.js-sticky'));
#   });
#
#   if (!true) {
#     document.addEventListener('admeiraavailable', function() {
#       var containers = Array.from(document.getElementsByClassName('js-admeira-container')).map(function(elem) {
#         if (getComputedStyle(elem).display !== 'none') {
#           return {
#             container: elem,
#             slot: elem.dataset.adSlot
#           }
#         }
#       });
#
#       containers = containers.filter(function (e) { return e !== undefined; });
#
#       var platform = false ? 'MobileWeb' : 'Desktop';
#       var channel = 'DetailEntryPrivate';
#
#       window.localAdmeira.init(containers, platform, channel);
#     });
#   };
# </script>
# <script async="" defer="" onload="window.initMap()" src="https://map.search.ch/api/map.js?lang=en"></script>
# <script>
#   window.jQuery(function ($) { $('#js-contact-57ce[data-overlay]').contentOverlay(); });
# </script>
# <script>
#   window.jQuery(function ($) { $('.js-scroll-to-feedback').scrollToFeedback() });
# </script>
# <script>
#   window.jQuery(function ($) {
#     $('#js-tiny-gallery-c705')
#       .gallery()
#       .tinyGallerySlide();
#   });
# </script>
# <script>
#   window.jQuery(function ($) {
#     $('#js-opening-hours-full-cb0e-link').collapsible();
#   });
# </script>
# <script>
#   window.jQuery(function ($) {
#     $('.js-contact-overlay').contentOverlay();
#
#     // Copy to clipboard posibility should be available when the content is shown and isn't blocked.
#     $('.js-copy-to-clipboard').on('content:show', function () {
#       $(this).copyToClipboard();
#     });
#   });
# </script>
# <script>
#   window.jQuery(function ($) {
#     $('#js-opening-hours-full-3cff-link').collapsible();
#   });
# </script>
# <script>
#   window.jQuery(function ($) { $('#js-routing-map-4059').placeMap(); });
# </script>
# <script>
#   window.jQuery(function ($) { $('#js-routing-bd66').routing(); });
# </script>
# <script>
#   window.jQuery(function ($) { $('#js-description-bbbc').description(); });
# </script>
# <script>
#   window.jQuery(function ($) {
#     $('#js-categories-links-44e7-link').collapsible();
#   });
# </script>
# <script>
#   // This script must be run after all :additional_scripts from the views
#   window.jQuery(function ($) {
#     var $routingModal = $('.js-mobile-routing-gtm');
#     var openMap = (window.location.hash.substr(1) === 'map') && $routingModal;
#
#     if (openMap && !window.mobileHelper.isMobile()) {
#       window.gtmEvent($routingModal.modal('show')[0]);
#     }
#   });
# </script>
# </body>
# </html>

# %%
sp.find('div', "feedback-summary-ratings-value lui-margin-bottom-xxs").find('span', class_ = "feedback-summary-ratings-average lui-font-bold").text
# Out:
# '3.6'

# %%
ap = sp.find('div', "text-muted text-nowrap lui-margin-top-xs").text

# %%
ap.split('| ')[1].strip()
# Out:
# '3 reviews'

# %%
find('span', class_ = "feedback-summary-ratings-average lui-font-bold").text
