# %%
import mpl_toolkits
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2244\2572502356.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
df = pd.read_csv('Swiz_clinc.csv')

# %%
# Load the data into a GeoDataFrame
df = pd.DataFrame({'Names': ['Gesundheitszentrum Fricktal AG', 'Klinik Professor Sailer', 'Kantonsspital Baselland Liestal', 'Klinik Wysshölzli', 'Centre Jean-Violette'],
                   'Latitude': [47.508943, 47.369394, 47.488018, 47.184946, 46.194171],
                   'Longitude': [8.016782, 8.566445, 7.731157, 7.715649, 6.144164]})

# Create a geometry column with the latitude and longitude
df['geometry'] = gpd.points_from_xy(df.Longitude, df.Latitude)
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# Plot the data on a map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='white', edgecolor='black', figsize=(15,10))
gdf.plot(ax=ax, markersize=100, color='red')

plt.show()

# %%
# drop NaN values from the dataframe
df = df.dropna()

# plot the latitude and longitude with the ratings and reviews
plt.figure(figsize = (15, 7))
plt.scatter(df['Longitude'], df['Latitude'], c=df['Rating'], s=df['Reviews'] * 29 , cmap='viridis')
plt.colorbar()

# set the x and y axis labels
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# show the plot
plt.show()

# %%
# create a dataframe with latitude and longitude
df = pd.DataFrame({'latitude': [45.5236, 43.6532, 40.7128, 37.7749, 34.0522],
                   'longitude': [-122.6750, -79.3832, -74.0060, -122.4194, -118.2437]})

# create a figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

# create a basemap with a low resolution coastlines
m = Basemap(resolution='l', llcrnrlat=-90, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, ax=ax)
m.drawcoastlines()

# plot the latitude and longitude on the basemap
m.scatter(df['longitude'], df['latitude'], latlon=True, c='red', s=100)

# add title and show the plot
plt.title("Latitude and Longitude on a Map using Basemap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11640\1400678115.py in <module>
#      11
#      12 # create a basemap with a low resolution coastlines
# ---> 13 m = Basemap(resolution='l', llcrnrlat=-90, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, ax=ax)
#      14 m.drawcoastlines()
#      15
#
# NameError: name 'Basemap' is not defined
